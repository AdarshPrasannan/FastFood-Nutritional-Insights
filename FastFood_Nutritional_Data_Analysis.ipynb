# %% [markdown]
# <h1>FAST FOOD NUTRITION DATA ANALYSIS</h1>

# %% [markdown]
# <h2>🎯 Aim of the Project</h2>
#
# To analyze fast-food nutritional data in order to compare menu items across major fast-food chains and generate insights that support healthier and more informed food choices.

# %% [markdown]
# <h2>📝 Objective of the Project</h2>
#
# The main goal of this project is to analyze fast-food nutritional data to understand:
#
# - Nutritional differences across major fast-food chains
#
# - Healthiest and unhealthiest menu items
#
# - How calories, fat, cholesterol, carbohydrates, fiber, protein, sugar, and sodium vary across items
#
# - How Weight Watchers Points relate to nutrition levels
#
# -Patterns that can help customers make healthier choices
#
# This analysis helps in understanding nutritional quality, comparing brands, and identifying trends that support better food decisions.

# %% [markdown]
# <h2>📂 About the Dataset</h2>
#
# <h4>● Source URL:</h4>
#
# Kaggle – https://www.kaggle.com/code/devraai/fast-food-nutrition-data-analysis-and-modeling/input
#
# <h4>● Data Type:</h4>
#
# CSV (Comma Separated Values)
#
# <h4>● Rows:</h4>
#
# 1148 menu items
#
# <h4>● Columns:</h4>
#
# The dataset includes information about the company and menu item, along with multiple nutritional features such as calories, calories from fat, total fat, saturated fat, trans fat, cholesterol, sodium, carbohydrates, fiber, sugars, protein, and Weight Watchers Points.
#
# <h4>● Data Collected From:</h4>
#
# Major fast-food chains in the US
#
# <h4>● Fast-Food Chains Included:</h4>
#
#   -  McDonald's
#
#   - KFC
#
#   - Burger King
#
#   - Taco Bell
#
#   - Pizza Hut
#
#   - Wendy's

# %% [markdown]
# <h2>🪜 Steps:</h2>
#
# - Data loading and initial overview
#
# - Data Pre-processing
#
# - Exploratory Data Analysis (EDA) and Visualizations
#
# - Insight Generation and Report

# %% [markdown]
# <h1>Step 1: Data Loading and Initial Overview</h1>

# %% [markdown]
# <h2>📚 Import Required Libraries</h2>
#
# To begin working with the dataset, we import the essential Python libraries:
#
# - Pandas – for data loading, manipulation, and analysis
# - NumPy – for numerical operations and array handling

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2>📥 Read Data</h2>

# %% [markdown]
# To begin working with our dataset, we use the pandas.read_csv() function, which allows us to load CSV files into a Pandas DataFrame. A DataFrame is a table-like structure where we can easily clean, analyze, and visualize our data.
#
# The file path passed inside read_csv() can be:
#
# - A local file path (e.g., "data/fastfood.csv")
#
# - An online URL
#
# Pandas will read the file from the given location and store it in the variable we assign.

# %%
df = pd.read_csv("FastFoodNutritionMenuV2.csv")

# %% [markdown]
# <h2>👀 Viewing the Dataset</h2>

# %% [markdown]
# Once we have successfully loaded the dataset into a Pandas DataFrame, the next step is to explore its structure. Pandas provides several useful functions to help us understand the data before applying any cleaning or preprocessing.

# %% [markdown]
# <h2>Display First Few Rows</h2>

# %% [markdown]
# - head() – View the first few rows
#
# The head() function displays the first 5 rows of the dataset by default.
# It helps us quickly verify that the data has loaded correctly and observe the column structure.

# %%
print("The first 5 rows of the dataframe:")
df.head(5)
# Out:
# The first 5 rows of the dataframe:
#       Company                           Item Calories Calories from\nFat  \
# 0  McDonald’s                      Hamburger      250                 80
# 1  McDonald’s                   Cheeseburger      300                110
# 2  McDonald’s            Double Cheeseburger      440                210
# 3  McDonald’s                       McDouble      390                170
# 4  McDonald’s   Quarter Pounder® with Cheese      510                230
#
#   Total Fat\n(g) Saturated Fat\n(g) Trans Fat\n(g) Cholesterol\n(mg)  \
# 0              9                3.5            0.5                25
# 1             12                  6            0.5                40
# 2             23                 11            1.5                80
# 3             19                  8              1                65
# 4             26                 12            1.5                90
#
#   Sodium \n(mg) Carbs\n(g) Fiber\n(g) Sugars\n(g) Protein\n(g)  \
# ...

# %% [markdown]
# <h2>Dimensions of the Dataset</h2>

# %% [markdown]
# - shape – Check the dimensions of the dataset
#
# The shape attribute tells us:
#
#   - Number of rows
#
#   - Number of columns
#
# This helps us understand how large the dataset is.

# %%
print("The shape (rows, columns) of the dataframe:")
df.shape
# Out:
# The shape (rows, columns) of the dataframe:
# (1148, 14)

# %% [markdown]
# <h2>Dataset Summary: Data Types & Missing Values</h2>

# %% [markdown]
# - info() – View column types and missing values
#
# The info() function provides:
#
#   - Data types of each column
#
#   - Number of non-null values
#
#   - Memory usage
#
# This is important for identifying missing values and incorrect data types.

# %%
print("Information about the dataframe:")
df.info()
# Out:
# Information about the dataframe:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1148 non-null   object
#  1   Item                  1148 non-null   object
#  2   Calories              1147 non-null   object
#  3   Calories from
# Fat     642 non-null    object
#  4   Total Fat
# (g)         1091 non-null   object
#  5   Saturated Fat
# (g)     1091 non-null   object
#  6   Trans Fat
# (g)         1091 non-null   object
#  7   Cholesterol
# (mg)      1147 non-null   object
#  8   Sodium
# (mg)          1147 non-null   object
#  9   Carbs
# (g)             1091 non-null   object
#  10  Fiber
# (g)             1091 non-null   object
#  11  Sugars
# (g)            1147 non-null   object
#  12  Protein
# (g)           1091 non-null   object
#  13  Weight Watchers
# Pnts  887 non-null    object
# ...

# %% [markdown]
# <h2>Summary Statistics of Numerical Features</h2>

# %% [markdown]
# - describe() – Summary statistics
#
# The describe() function shows statistical summaries for numerical columns:
#
#   - Mean
#
#   - Standard deviation
#
#   - Min/Max
#
#   - Quartiles
#
# This helps us understand the distribution of the numerical features.

# %%
print("Statistical summary of the dataframe:")
df.describe()
# Out:
# Statistical summary of the dataframe:
#            Company      Item Calories Calories from\nFat Total Fat\n(g)  \
# count         1148      1148     1147                642           1091
# unique           6      1072      105                 64             73
# top     McDonald’s  20 fl oz        0                  0              0
# freq           329        11       83                175            357
#
#        Saturated Fat\n(g) Trans Fat\n(g) Cholesterol\n(mg) Sodium \n(mg)  \
# count                1091           1091              1147          1147
# unique                 35             11                65           214
# top                     0              0                 0             0
# freq                  383            954               378            54
#
#        Carbs\n(g) Fiber\n(g) Sugars\n(g) Protein\n(g) Weight Watchers\nPnts
# count        1091       1091        1147         1091                   887
# ...

# %% [markdown]
# <h1>Step 2: Data Pre-processing</h1>

# %% [markdown]
# Data pre-processing is an essential step in any data analysis workflow. It ensures the dataset is clean, consistent, and ready for deeper analysis. In this section, we perform several important operations to improve the quality of our data.

# %% [markdown]
# <h2>♻️ Removing Duplicates</h2>

# %% [markdown]
# Duplicate entries can distort statistical summaries and create bias in analysis. We identify and remove duplicate rows to ensure the dataset contains only unique records.

# %%
print("Number of duplicate rows before removal:", df.duplicated().sum())

df = df.drop_duplicates()

print("Number of duplicate rows after removal:", df.duplicated().sum())
# Out:
# Number of duplicate rows before removal: 7
# Number of duplicate rows after removal: 0

# %% [markdown]
# <h2>🛠️ Cleaning Column Values & Correcting Data Types</h2>

# %% [markdown]
# Real-world datasets often contain inconsistent, messy, or incorrectly formatted values. These issues may arise from manual data entry, file formatting differences, or data exported from external sources.
# Before performing any analysis, it is essential to clean column values and correct data types to ensure the dataset is accurate and usable.
#
# Cleaning column values helps remove:
#
# - Extra spaces, tabs, and newline characters
#
# - Hidden non-breaking spaces (\xa0)
#
# - Unwanted characters and symbols
#
# - Text mixed with numeric values
#
# This step makes the data consistent, easier to read, and ready for proper numeric conversion and analysis.
#
# Datasets often contain incorrect or inconsistent data types—for example:
#
# - Dates stored as strings
#
# - Numbers stored as text
#
# - Categorical fields mistakenly treated as numerical
#
# Correcting data types allows efficient filtering, grouping, and computations.

# %%
df.columns = (
    df.columns
      .str.replace('\n', ' ', regex=False)   
      .str.replace(r'\s+', ' ', regex=True)  
      .str.strip()                            
)

print("Step 1 completed: Column names cleaned!\n")
print(df.columns.tolist())

numeric_cols = [
    "Calories", "Calories from Fat", "Total Fat (g)", "Saturated Fat (g)",
    "Trans Fat (g)", "Cholesterol (mg)", "Sodium (mg)", "Carbs (g)",
    "Fiber (g)", "Sugars (g)", "Protein (g)", "Weight Watchers Pnts"
]

for col in numeric_cols:
    df[col] = (
        df[col].astype(str)                               
                .str.replace(r'[^0-9.-]', '', regex=True) 
                .replace('', np.nan)                      
                .astype(float)                            
    )

print("\nStep 2 completed: Numeric columns cleaned and converted to float!\n")
print(df[numeric_cols].dtypes)

text_cols = df.columns.difference(numeric_cols)

for col in text_cols:
    df[col] = (
        df[col].astype(str)                           
                .str.replace('\xa0', ' ', regex=False) 
                .str.replace(r'\s+', ' ', regex=True)  
                .str.strip()                           
    )

print("\nStep 3 completed: Text columns cleaned and formatted!\n")
print(df[text_cols].head())

df = df.convert_dtypes()  

print("\nStep 4 completed: Data types corrected!\n")
print(df.dtypes)

print("\nFinal Cleaned Dataset Preview:")
df.head()
# Out:
# Step 1 completed: Column names cleaned!
#
# ['Company', 'Item', 'Calories', 'Calories from Fat', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)', 'Carbs (g)', 'Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Weight Watchers Pnts']
#
# Step 2 completed: Numeric columns cleaned and converted to float!
#
# Calories                float64
# Calories from Fat       float64
# Total Fat (g)           float64
# Saturated Fat (g)       float64
# Trans Fat (g)           float64
# Cholesterol (mg)        float64
# Sodium (mg)             float64
# Carbs (g)               float64
# Fiber (g)               float64
# Sugars (g)              float64
# Protein (g)             float64
# Weight Watchers Pnts    float64
# dtype: object
#
# Step 3 completed: Text columns cleaned and formatted!
#
#       Company                          Item
# 0  McDonald’s                     Hamburger
# 1  McDonald’s                  Cheeseburger
# ...

# %% [markdown]
# <h2>🏷️ Derived Food Category Feature</h2>

# %% [markdown]
# To improve analysis and group similar food items, we create a derived categorical column called “Category” based on the food item names.
# This column assigns each item to one of 15 meaningful food categories, making it easier to analyze trends, compare item types, and visualize patterns across different fast-food menus.
#
# We use a custom function categorize_food() that checks for keywords inside each item name and classifies the item into one of the following 15 categories:
#
# List of All 15 Food Categories
#
# - Burger
#
# - Chicken Sandwich / Wrap
#
# - Nuggets / Wings / Tenders
#
# - Breakfast
#
# - Side
#
# - Salad
#
# - Dessert
#
# - Pizza
#
# - Taco
#
# - Burrito
#
# - Nachos
#
# - Bowl
#
# - Drink
#
# - Kids Menu
#
# - Condiment / Sauce
#
# - Other (fallback category)
#
# This ensures that every item is systematically classified, enabling cleaner filtering, consistent grouping, and better visual analytics.

# %%
def categorize_food(item):
    item = item.lower()

    # Burgers
    if any(k in item for k in ["burger", "whopper", "baconator", "king", "stacker"]):
        return "Burger"

    # Chicken Sandwiches / Wraps
    if any(k in item for k in ["chicken sandwich", "mcchicken", "crispy chicken", "spicy chicken",
                               "twister", "wrap", "club", "grilled chicken"]):
        return "Chicken Sandwich / Wrap"

    # Nuggets / Wings
    if any(k in item for k in ["nugget", "wing", "popcorn chicken", "tender", "strips"]):
        return "Nuggets / Wings / Tenders"

    # Breakfast
    if any(k in item for k in ["egg", "mcmuffin", "biscuit", "croissan", "griddle",
                               "breakfast", "hotcake", "hash brown"]):
        return "Breakfast"

    # Sides
    if any(k in item for k in ["fries", "onion rings", "coleslaw", "potato", "baked potato",
                               "beans", "corn", "side", "croutons"]):
        return "Side"

    # Salads
    if "salad" in item:
        return "Salad"

    # Desserts
    if any(k in item for k in ["sundae", "cookie", "pie", "mcflurry", "frosty", "cinnamon",
                               "parfait", "ice cream", "cone", "cake", "delight", "twists"]):
        return "Dessert"

    # Pizza
    if any(k in item for k in ["pizza", "slice", "pan pizza", "hand tossed"]):
        return "Pizza"

    # Tacos
    if "taco" in item:
        return "Taco"

    # Burritos
    if "burrito" in item or "quesarito" in item:
        return "Burrito"

    # Nachos
    if "nacho" in item:
        return "Nachos"

    # Bowls
    if "bowl" in item:
        return "Bowl"

    # Drinks
    if any(k in item for k in ["coke", "pepsi", "sprite", "fanta", "dr pepper", "root beer",
                               "juice", "tea", "coffee", "frappe", "shake", "smoothie",
                               "milk", "water", "lemonade"]):
        return "Drink"

    # Kids
    if any(k in item for k in ["happy meal", "kids", "kid", "jr"]):
        return "Kids Menu"

    # Condiments
    if any(k in item for k in ["sauce", "packet", "ketchup", "mayo", "mustard", "jam", "jelly"]):
        return "Condiment / Sauce"

    return "Other"

df.insert(
    df.columns.get_loc("Item") + 1,
    "Category",
    df["Item"].apply(categorize_food)
)

print("Derived Columns Created:")
print(df.head(10))
# Out:
# Derived Columns Created:
#       Company                                 Item Category  Calories  \
# 0  McDonald’s                            Hamburger   Burger       250
# 1  McDonald’s                         Cheeseburger   Burger       300
# 2  McDonald’s                  Double Cheeseburger   Burger       440
# 3  McDonald’s                             McDouble    Other       390
# 4  McDonald’s         Quarter Pounder® with Cheese    Other       510
# 5  McDonald’s  Double Quarter Pounder® with Cheese    Other       740
# 6  McDonald’s                             Big Mac®    Other       540
# 7  McDonald’s                        Big N’ Tasty®    Other       460
# 8  McDonald’s            Big N’ Tasty® with Cheese    Other       510
# 9  McDonald’s                 Angus Bacon & Cheese    Other       790
#
#    Calories from Fat  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 0                 80            9.0                3.5            0.5
# ...

# %% [markdown]
# <h2>🩹 Missing Value Handling (Category-Wise Imputation)</h2>

# %% [markdown]
# In this step, we clean the dataset by handling missing values across all nutritional attributes.
# Since food items belong to different menu categories (such as Burgers, Drinks, Salads, etc.), imputing missing values globally may distort the statistics.
#
# To ensure more meaningful and accurate imputation, we apply the following strategy:
#
# - Convert All Numeric Columns to Float
# Some numeric columns use pandas’ nullable Int64 dtype, which cannot hold decimal values.
# Because category-wise mean values are often decimals, we convert all numeric columns to float to avoid datatype errors.
#
# - Category-Wise Mean Imputation
# For each numeric column:
# The dataset is grouped by Category
# Missing values are replaced with the mean value of that category
# This preserves the nutritional pattern of each menu type
# (e.g., Burgers tend to have higher calories than Drinks)
#
# - Global Mean Fallback
# If a category contains all missing values for a column, its mean is NaN.
# Such remaining missing values are filled using the overall column mean to ensure the dataset contains no missing numeric values.

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64', 'Int64']).columns
df[numeric_cols] = df[numeric_cols].astype(float)

print( "Null Values BEFORE Imputation:\n")
print(df.isnull().sum())

for col in numeric_cols:
    df[col] = df.groupby("Category")[col].transform(
        lambda x: x.fillna(x.mean())
    )

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

print("\nNull Values AFTER Imputation:\n")
print(df.isnull().sum())
# Out:
# Null Values BEFORE Imputation:
#
# Company                   0
# Item                      0
# Category                  0
# Calories                 15
# Calories from Fat       518
# Total Fat (g)            69
# Saturated Fat (g)        69
# Trans Fat (g)            69
# Cholesterol (mg)         15
# Sodium (mg)              15
# Carbs (g)                69
# Fiber (g)                69
# Sugars (g)               15
# Protein (g)              69
# Weight Watchers Pnts    272
# dtype: int64
#
# Null Values AFTER Imputation:
#
# Company                 0
# Item                    0
# Category                0
# Calories                0
# Calories from Fat       0
# Total Fat (g)           0
# Saturated Fat (g)       0
# Trans Fat (g)           0
# Cholesterol (mg)        0
# Sodium (mg)             0
# Carbs (g)               0
# Fiber (g)               0
# Sugars (g)              0
# Protein (g)             0
# Weight Watchers Pnts    0
# dtype: int64

# %% [markdown]
# <h2>🧮 Derived Nutritional Classification Features</h2>

# %% [markdown]
# To better understand and categorize the nutritional values in the dataset, we create derived categorical columns for each numeric variable. These derived columns classify the values into three meaningful groups:
#
# - Low
#
# - Mid
#
# - High
#
# This helps simplify analysis, enables better comparisons, and is especially useful for visualization and pattern detection.
#
# We use pandas.cut() with:
# bins=3
#
# This splits the range of values for each numeric column into three equal-width intervals, assigning each value to either:
#
# - Low
#
# - Mid
#
# - High
#
# This approach avoids errors caused by repeated percentile values and ensures stable, consistent categorization.

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

def create_category_column(series):
    return pd.cut(series, bins=3, labels=["Low", "Mid", "High"])

for col in numeric_cols:
    cat_col = f"{col} Category"
    df.insert(df.columns.get_loc(col) + 1, cat_col, create_category_column(df[col]))

category_cols = [col for col in df.columns if "Category" in col]

print("Derived Columns Created:")
print(category_cols)

print("\nSample of Derived Columns:")
df[category_cols].head()
# Out:
# Derived Columns Created:
# ['Category', 'Calories Category', 'Calories from Fat Category', 'Total Fat (g) Category', 'Saturated Fat (g) Category', 'Trans Fat (g) Category', 'Cholesterol (mg) Category', 'Sodium (mg) Category', 'Carbs (g) Category', 'Fiber (g) Category', 'Sugars (g) Category', 'Protein (g) Category', 'Weight Watchers Pnts Category']
#
# Sample of Derived Columns:
#   Category Calories Category Calories from Fat Category  \
# 0   Burger               Low                        Low
# 1   Burger               Low                        Low
# 2   Burger               Mid                        Low
# 3    Other               Low                        Low
# 4    Other               Mid                        Low
#
#   Total Fat (g) Category Saturated Fat (g) Category Trans Fat (g) Category  \
# 0                    Low                        Low                    Low
# 1                    Low                        Low                    Low
# ...

# %% [markdown]
# <h2>📝 Final Data Inspection and Export</h2>

# %% [markdown]
# Once the dataset has been fully cleaned, processed, and enhanced with derived columns, it is important to:
#
# - Verify the final structure of the data, and
#
# - Save the cleaned dataset as a new file for sharing, reporting, or further analysis.

# %% [markdown]
# <h2>Viewing the Preprocessed Dataset</h2>
#
# Before exporting, we can take a quick look at the cleaned dataset to ensure:
#
# - All missing values are handled
#
# - Column names are properly formatted
#
# - Numeric columns are correctly converted
#
# - Derived columns are added

# %%
df.head()
# Out:
#       Company                          Item Category  Calories  \
# 0  McDonald’s                     Hamburger   Burger     250.0
# 1  McDonald’s                  Cheeseburger   Burger     300.0
# 2  McDonald’s           Double Cheeseburger   Burger     440.0
# 3  McDonald’s                      McDouble    Other     390.0
# 4  McDonald’s  Quarter Pounder® with Cheese    Other     510.0
#
#   Calories Category  Calories from Fat Calories from Fat Category  \
# 0               Low               80.0                        Low
# 1               Low              110.0                        Low
# 2               Mid              210.0                        Low
# 3               Low              170.0                        Low
# 4               Mid              230.0                        Low
#
#    Total Fat (g) Total Fat (g) Category  Saturated Fat (g)  ... Carbs (g)  \
# 0            9.0                    Low                3.5  ...      31.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1141 entries, 0 to 1147
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Company                        1141 non-null   string
#  1   Item                           1141 non-null   string
#  2   Category                       1141 non-null   object
#  3   Calories                       1141 non-null   float64
#  4   Calories Category              1141 non-null   category
#  5   Calories from Fat              1141 non-null   float64
#  6   Calories from Fat Category     1141 non-null   category
#  7   Total Fat (g)                  1141 non-null   float64
#  8   Total Fat (g) Category         1141 non-null   category
#  9   Saturated Fat (g)              1141 non-null   float64
#  10  Saturated Fat (g) Category     1141 non-null   category
#  11  Trans Fat (g)                  1141 non-null   float64
# ...

# %% [markdown]
# <h2>Saving the Cleaned Dataset</h2>
#
# - After successful preprocessing, we save the final dataset to a new CSV file.
#
# - This allows us to download it, share it, or use it in other applications.

# %%
df.to_csv("fastfood_nutrition_processed.csv", index=False)

print("✔ Cleaned dataset saved successfully as 'fastfood_nutrition_processed.csv'")
# Out:
# ✔ Cleaned dataset saved successfully as 'fastfood_nutrition_processed.csv'

# %% [markdown]
# <h1>Step 3: Exploratory Data Analysis (EDA) & Visualizations</h1>

# %% [markdown]
# Exploratory Data Analysis (EDA) is a critical step in understanding the structure, patterns, and relationships within a dataset. After preprocessing, EDA helps uncover meaningful insights using statistical summaries, comparisons, and visualizations.
# This section combines both descriptive analysis and graphical exploration.

# %% [markdown]
# <h2>📚 Importing Required Visualization Libraries</h2>
#
# To create plots and visualizations in Python, we use two main libraries:
#
# - Matplotlib: The foundational plotting library in Python.
# Used for basic charts like line plots, bar charts, scatter plots, etc.
#
# - Seaborn: A powerful visualization library built on top of Matplotlib.
# Provides advanced statistical plots with clean visuals.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h2>📈 Univariate Analysis</h2>
#
# Univariate analysis focuses on examining one variable at a time.
# This helps us understand the individual characteristics of each feature in the dataset.

# %% [markdown]
# <h2>📊Distribution of Calories</h2>
#
# Understanding the distribution of calorie values helps identify how calorie levels vary across all food items.
# A histogram is a useful tool for visualizing the frequency of different calorie ranges, while the KDE (Kernel Density Estimate) curve provides a smoothed representation of the distribution.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Calories"], kde=True)
plt.title("Distribution of Calories")
plt.xlabel("Calories")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🧈Distribution of Total Fat</h2>
#
# Analyzing the distribution of total fat helps us understand how much fat is present across different food items in the dataset.A histogram helps visualize the number of items falling into specific fat ranges.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Total Fat (g)"], kde=True)
plt.title("Distribution of Total Fat (g)")
plt.xlabel("Total Fat (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🧈Distribution of Saturated Fat</h2>
#
# Understanding the distribution of saturated fat helps reveal how fatty different food items are across the dataset.A histogram is useful for visualizing the frequency of various saturated fat levels.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Saturated Fat (g)"], kde=True)
plt.title("Distribution of Saturated Fat (g)")
plt.xlabel("Saturated Fat (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🫀 Distribution of Cholesterol</h2>
#
# Understanding the distribution of cholesterol values helps identify how cholesterol levels vary across different food items in the dataset.A histogram shows the frequency of cholesterol values across various ranges.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Cholesterol (mg)"], kde=True)
plt.title("Distribution of Cholesterol (mg)")
plt.xlabel("Cholesterol (mg)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🍞 Distribution of Carbohydrates </h2>
#
# Understanding how carbohydrate levels vary across food items is important for analyzing energy content and dietary impact.
# A histogram displays how often different carbohydrate ranges occur in the dataset.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Carbs (g)"], kde=True)
plt.title("Distribution of Carbs (g)")
plt.xlabel("Carbs (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🍬 Distribution of Sugars </h2>
#
# Analyzing the distribution of sugar content helps reveal how sweet or sugar-dense different food items are.
# A histogram displays how frequently various sugar levels appear in the dataset.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Sugars (g)"], kde=True)
plt.title("Distribution of Sugars (g)")
plt.xlabel("Sugars (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🌾 Distribution of Fiber </h2>
#
# Understanding the distribution of fiber content helps us see how much dietary fiber different food items contain.A histogram visualizes the frequency of items across different fiber ranges.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Fiber (g)"], kde=True)
plt.title("Distribution of Fiber (g)")
plt.xlabel("Fiber (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🧂 Distribution of Sodium </h2>
#
# Sodium content is a key nutritional factor, especially in fast food items where salt levels can vary widely.
# A histogram helps visualize how frequently different sodium levels occur.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Sodium (mg)"], kde=True)
plt.title("Distribution of Sodium (mg)")
plt.xlabel("Sodium (mg)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🥩 Distribution of Protein </h2>
#
# Understanding the distribution of protein content helps assess how much nutritional value different food items provide.
# A histogram shows how frequently various protein levels occur across the dataset.

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Protein (g)"], kde=True)
plt.title("Distribution of Protein (g)")
plt.xlabel("Protein (g)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h2>🏢Number of Items per Company</h2>
#
# Understanding how many menu items each company contributes to the dataset helps establish the distribution of data across different fast-food chains.
# A countplot is useful for visualizing the frequency of items for each company

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x="Company")
plt.title("Number of Items per Company")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🌾 Fiber Levels Across Categories</h2>
#
# A boxen plot (also known as a letter-value plot) is an extended version of the traditional box plot.
# It is especially useful when working with large datasets, because it provides a more detailed view of the distribution by showing multiple layers of quantiles rather than just the median and interquartile range.
#
# This visualization helps you understand how fiber levels vary across the Low, Mid, and High fiber categories.

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(data=df, x="Fiber (g) Category", y="Fiber (g)")
plt.title("Fiber Levels by Category")
plt.xlabel("Fiber (g) Category")
plt.ylabel("Fiber (g)")
plt.show()

# %% [markdown]
# <h2>🧂 Distribution of Sodium Levels Across Categories </h2>
#
# A boxen plot (also called a letter-value plot) is an extension of the traditional box plot and is particularly useful for visualizing large datasets.
# It provides a more detailed summary of the distribution by breaking the data into multiple quantiles.
#
# This visualization helps you understand how sodium levels vary across Low, Mid, and High sodium categories.

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(data=df, x="Sodium (mg) Category", y="Sodium (mg)")
plt.title("Sodium Levels by Category")
plt.xlabel("Sodium (mg) Category")
plt.ylabel("Sodium (mg)")
plt.show()

# %% [markdown]
# <h2>🍗 Protein Levels Across Categories</h2>
#
# A boxen plot (also called a letter-value plot) is an enhanced version of the traditional box plot and is particularly useful when analyzing large datasets.
#
# This visualization helps you understand how protein levels vary across the Low, Mid, and High protein categories.

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(data=df, x="Protein (g) Category", y="Protein (g)")
plt.title("Protein Levels by Category")
plt.xlabel("Protein (g) Category")
plt.ylabel("Protein (g)")
plt.show()

# %% [markdown]
# <h2>🔀 Bivariate Analysis</h2>
#
# Bivariate analysis studies the relationship between two variables at a time.
# It reveals how one feature influences or interacts with another.

# %% [markdown]
# <h2>🔥 Average Calories per Company</h2>
#
# A heatmap is an excellent tool for visualizing aggregated numerical values across categories.
# In this case, it shows the average calories offered by each company, helping us compare calorie levels across different fast-food chains.

# %%
pivot = df.pivot_table(values="Calories", index="Company", aggfunc="mean")

plt.figure(figsize=(8,4))
sns.heatmap(pivot, annot=True, cmap="YlOrRd")
plt.title("Average Calories per Company")
plt.show()

# %% [markdown]
# <h2>🍽️ Calorie Categories by Company</h2>
#
# This visualization compares how different companies distribute their menu items across Low, Mid, and High calorie categories.
# Using a countplot with a hue (Calories Category) allows us to clearly see:
#
# How many menu items each company offers
#
# Which calorie category dominates for each company

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Company", hue="Calories Category")
plt.title("Calorie Categories by Company")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🧈 Fat Categories by Company</h2>
#
# This countplot shows how different companies distribute their menu items across Low, Mid, and High fat categories.
# By adding a hue for Total Fat (g) Category, this visualization clearly highlights how fat levels vary among companies.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Company", hue="Total Fat (g) Category")
plt.title("Fat Categories by Company")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🍞 Carbohydrate Categories by Company</h2>
#
# This countplot visualizes how different companies distribute their menu items across Low, Mid, and High carbohydrate categories

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Company", hue="Carbs (g) Category")
plt.title("Carbs Categories by Company")
plt.xlabel("Company")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🍬 Sugar Categories by Company</h2>
#
# This countplot shows how different companies distribute their menu items across Low, Mid, and High sugar categories.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Company", hue="Sugars (g) Category")
plt.title("Sugar Categories by Company")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🔍 Relationship Between Total Fat and Calories</h2>
#
# A scatter plot is a useful visualization for analyzing the relationship between two continuous variables.
# In this case, the plot shows how Total Fat (g) relates to Calories across different menu items, with each point colored by company.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="Total Fat (g)", y="Calories", hue="Company", data=df)
plt.title("Calories vs Total Fat")
plt.show()

# %% [markdown]
# <h2>🍽️ Average Calories by Food Category</h2>
#
# This horizontal bar chart visualizes the average calorie content for each food category in the dataset.
# Using a horizontal layout makes it easier to compare categories, especially when category names are long or numerous.

# %%
plt.figure(figsize=(14,8))
sns.barplot(y="Category", x="Calories", data=df, estimator=np.mean, errorbar=None)
plt.title("Average Calories by Food Category")
plt.xlabel("Average Calories")
plt.ylabel("Food Category")
plt.show()

# %% [markdown]
# <h2>🌾 Fiber Levels Across Companies </h2>
# A boxen plot (letter‐value plot) is an enhanced version of a box plot designed to show detailed distribution information, especially in larger datasets.
# This visualization compares Fiber (g) levels across different companies to help reveal variations in nutritional composition.

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(x="Company", y="Fiber (g)", data=df)
plt.title("Fiber Levels Across Companies")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🧂 Sodium Levels Across Companies </h2>
#
# A boxen plot (letter-value plot) is an enhanced version of a traditional box plot.
# It is especially useful for larger datasets because it displays multiple quantiles, offering a more detailed view of the distribution.
#
# In this visualization, the boxen plot compares Sodium (mg) levels across different companies.

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(x="Company", y="Sodium (mg)", data=df)
plt.title("Sodium Levels Across Companies")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🥩 Protein Levels Across Companies </h2>
#
# A boxen plot (letter-value plot) offers a detailed look at how protein content varies across different companies.
# It expands on the traditional boxplot by showing more quantiles, making it ideal for identifying subtle patterns in larger datasets.
#
# This visualization allows us to observe which companies tend to offer higher-protein menu items and variability of protein content within each company.

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(x="Company", y="Protein (g)", data=df)
plt.title("Protein Levels Across Companies")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>⭐ Average Weight Watchers Points by Company </h2>
#
# A point plot is ideal for visualizing the average value of a numerical variable across different categorical groups.
# In this case, the plot shows the average Weight Watchers Points assigned to menu items for each company.
#
# Weight Watchers Points provide a combined measure of calories, fat, fiber, and protein — making this visualization useful for comparing the overall healthiness of menu items from different fast-food brands.

# %%
plt.figure(figsize=(14,8))
sns.pointplot(x="Company", y="Weight Watchers Pnts", data=df, errorbar=("ci", 95))
plt.title("Average Weight Watchers Points by Company")
plt.xlabel("Company")
plt.ylabel("Average Weight Watchers Points")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>🧩 Multivariate Analysis</h2>
#
# Multivariate analysis examines interactions among three or more variables simultaneously.
# It reveals complex patterns not visible in univariate or bivariate analysis.

# %% [markdown]
# <h2>🔥 Nutritional Feature Correlation Matrix</h2>
#
# A correlation heatmap is a powerful tool for identifying relationships between numerical variables.
# In this visualization, only numerical nutritional features are selected (e.g., Calories, Fat, Sodium, Carbs, Sugars, Protein, etc.), and their pairwise correlations are calculated.

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df.select_dtypes(include="float64").corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap of Nutritional Features")
plt.show()

# %% [markdown]
# <h2>🔍Multivariate Relationship Analysis of Nutritional Features</h2>
#
# A pairplot provides a comprehensive multivariate visualization by generating scatterplots for every pair of numerical variables along with histograms of individual features.
# Using a hue for Company makes it possible to compare nutrient relationships across different fast-food brands.

# %%
sns.pairplot(
    df,
    vars=[
        "Calories",
        "Total Fat (g)",
        "Sodium (mg)",
        "Carbs (g)",
        "Sugars (g)",
        "Protein (g)"
    ],
    hue="Company",
    corner=True
)
plt.show()

# %% [markdown]
# <h2>🍽️ Average Nutritional Values Across Companies </h2>
#
# This grouped bar chart provides a clear comparison of average nutritional values across different fast-food companies.Because the chart displays multiple nutrients simultaneously, it provides an excellent high-level comparison of nutritional composition across companies.

# %%
nutrient_cols = [
    "Calories",
    "Total Fat (g)",
    "Cholesterol (mg)",
    "Fiber (g)",
    "Sodium (mg)",
    "Carbs (g)",
    "Sugars (g)",
    "Protein (g)"
]
grouped = df.groupby("Company")[nutrient_cols].mean()

# Plot grouped bar chart
plt.figure(figsize=(18,10))
grouped.plot(kind="bar", figsize=(16,8))
plt.title("Average Nutrition Values per Company")
plt.ylabel("Average Values")
plt.xlabel("Company")
plt.xticks(rotation=45)
plt.legend(title="Nutrients", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# <h1>Step 4: Key Findings and Analysis Summary </h1>

# %% [markdown]
# Based on the univariate, bivariate, and multivariate analysis performed on the fast-food nutrition dataset (McDonald’s, Burger King, KFC, Wendy’s, Taco Bell, Pizza Hut), the following key insights were identified:

# %% [markdown]
# <h2>📉 Overall Nutritional Patterns</h2>
#
# - **Calories:** Most menu items fall within the 200–500 calorie range, indicating that fast food is generally moderate to high in energy content.             Extremely   high-calorie items exist mainly in oversized burgers, nachos, burritos, and combo meals.
#
# - **Total Fat & Saturated Fat:** Fat is a major contributor to calorie load. Many items contain high levels of total fat and saturated fat, especially        fried foods, burgers, and cheesy items.
#
# - **Carbohydrates:** Carbs vary widely across items, with burritos, wraps, sandwiches, and pizzas contributing to the highest carbohydrate values.
#
# - **Sugars:** Sugar levels show huge variation. Desserts, beverages, and sweetened sauces contain the highest sugar spikes, forming the extreme outliers in the dataset.
#
# - **Protein:** Protein levels range from low to high depending on the item. Meat-based items offer higher protein, but they often come paired with increased fat and calories, reducing their overall health profile.
#
# - **Fiber:** Fiber content is consistently low across most items, reflecting limited use of whole grains, vegetables, and high-fiber ingredients in mainstream fast-food menus.
#
# - **Sodium:** Sodium levels are consistently high, with many items exceeding recommended daily intake limits. This makes sodium the most concerning nutrient across all chains.

# %% [markdown]
# <h2>🏭 Nutrient Comparison Across Companies </h2>
#
# - **Burger King and Wendy’s** show noticeably higher average Calories, Total Fat, and Carbs, suggesting richer ingredients and larger portion sizes. Their menus also contain several high-protein items, but these often come with higher fat content. Fiber remains generally low across their offerings.
#
# - **Pizza Hut** shows lower variability in many nutrients because of its pizza-focused menu. However, items consistently exhibit high sodium, driven by processed meats and cheese. Protein levels are moderate, while fiber is relatively low because most items are refined-grain–based.
#
# - **McDonald's and KFC** display a wide nutrient range, offering everything from low-calorie, low-fat items (salads, grilled options) to extremely high-sodium and high-fat meals (fried chicken, large burgers, combos). Protein levels vary significantly, and fiber remains limited in most items other than wraps or certain sides.
#
# - **Taco Bell** tends to offer moderately high Carbs and moderate Protein, as most items involve tortillas, rice, beans, and mixed fillings. Sodium levels are consistently elevated, and some large burritos appear as high-calorie outliers. Though fiber content is slightly higher in items containing beans or vegetables, the overall menu remains carb-heavy and sodium-rich, with mostly mid-range calories compared to Burger King or Wendy’s.

# %% [markdown]
# <h2>🍱 Food Category Patterns </h2>
#
# - **Burgers, Sandwiches, Nachos and Burritos** have the highest average Calories, driven by high Total Fat, Carbohydrates, and Sodium.
# These categories also tend to be high in Protein due to meat content, but Fiber remains low because they rely mostly on refined breads, tortillas, and limited vegetables.
#
# - **Desserts and Beverages** contribute the highest Sugar levels, forming nearly all extreme sugar outliers in the dataset.
# They are typically high in Carbs and low in Fiber and Protein, making them nutritionally imbalanced despite their high energy content.
#
# - **Sides and Salads** tend to be lower in Calories, but nutrient levels depend on their composition.
# Salads with dressings or fried toppings can contain moderate to high Fat and Sodium, while plain vegetable-based sides offer higher Fiber and lower Sugar compared to most other categories.
#
# - **Wraps, Bowls, and Rice-based** items often have moderately high Carbs and Protein, with slightly better Fiber levels when beans or vegetables are included.
# However, sodium levels remain elevated in most cases due to sauces and seasoning.

# %% [markdown]
# <h2>🔍 Nutrient Interaction Summary</h2>
#
# - Nutrient levels (Calories, Fat, Carbs, Sugars, Sodium, Protein, Fiber) show wide variation across companies, meaning every chain offers both healthy and unhealthy items.
#
# - Chains with larger menus (e.g., McDonald's) appear more frequently across low, mid, and high nutrient categories in count-based visualizations.
#
# - Scatter plots show strong linear increases in Calories with Total Fat, indicating these nutrients heavily drive energy density.
#
# - Carbs and Sugars rise together across items, confirming their shared contribution to sweetness and high-calorie content.
#
# - Boxen and box plots demonstrate that nutrient distributions are highly spread, with several high-calorie and high-sodium outliers across chains.
#
# - The pairplot reveals company-specific nutrient clusters, meaning each brand has its own nutritional signature.
#
# - The correlation heatmap confirms major relationships:
#
#   - Calories ↔ Total Fat (strong)
#
#   - Calories ↔ Sodium (strong)
#
#   - Carbs ↔ Sugars (strong)
#
#   - Calories ↔ Weight Watchers Points (very strong)
#
#   - Protein ↔ Calories (moderate)
#
# - Overall, calories are influenced by multiple macronutrients, not just fat — carbs, sugars, sodium, and protein all contribute significantly.

# %% [markdown]
# <h2>📘 Key Insights from EDA </h2>

# %% [markdown]
# <h3>1. Overall Calorie Patterns</h3>
#
# - Most fast-food items fall in the 200–500 calorie range, confirming that the majority of items are calorie-dense.
#
# - Extremely high-calorie items are fewer and mainly found in burgers, burritos, and nachos.

# %% [markdown]
# <h3>2. Fat, Sodium, and Sugar Levels</h3>
#
# - Sodium levels are consistently very high across all companies, often exceeding recommended daily limits.
#
# - Sugar levels vary widely, with desserts, beverages, and sweetened items forming the highest spikes.
#
# - Total Fat strongly drives Calorie levels, showing a direct link between fat-based ingredients and energy density.

# %% [markdown]
# <h3>3. Protein and Fiber Distribution</h3>
#
# - Protein content varies widely between companies and categories, from low-protein snacks to high-protein meals.
#
# - Fiber levels are generally low, indicating limited whole grains or vegetables in most fast-food items.

# %% [markdown]
# <h3>4. Company-Level Nutrient Differences</h3>
#
# - Burger King and Wendy’s have higher average Calories, Fat, and Carbs, suggesting richer, heavier menu items.
#
# - Pizza Hut shows consistently high Sodium due to processed toppings and cheese-heavy items.
#
# - McDonald's, Taco Bell, and KFC show wide nutrient ranges, offering both light options and extreme nutrient outliers.

# %% [markdown]
# <h3>5. Category-Based Insights</h3>
#
# - Food category strongly influences nutrient levels:
#
# - Highest calories: Burgers, Burritos, Nachos
#
# - Highest sugars: Beverages and Desserts
#
# - Lowest nutrients (fiber/protein): Snacks, sides, some condiments
#
# - This confirms that the type of item matters more than the brand.

# %% [markdown]
# <h3>6. Nutrient Relationships</h3>
#
# - Strong positive correlations exist between:
#
# - Calories ↔ Total Fat
#
# - Calories ↔ Sodium
#
# - Carbs ↔ Sugars
#
# - Calories ↔ Weight Watchers Points
#
# - hese show that calorie content is driven by multiple macronutrients, not just fat.
#
# - These confirm that calories come from a combination of fats, carbs, sugars, and sodium — not just one nutrient.

# %% [markdown]
# <h3>7. High Variability & Outliers</h3>
#
# - Every company offers both healthy and unhealthy items.
#
# - Visualizations reveal extreme outliers in sodium (2000+ mg) and sugar (100+ g) that may significantly impact health.
#
# - This variability allows customers to choose healthier items—but also shows potential for reformulation.

# %% [markdown]
# <h3>8. Weight Watchers Points Insight</h3>
#
# - Weight Watchers Points rise sharply with increases in Calories, Fat, and Sugars, making them a useful single metric for estimating overall health impact.
#
# - Items with high WW Points consistently align with high-calorie, high-fat, or high-carb foods, making WW Points a strong indicator of nutritional density.

# %% [markdown]
# <h2>🧾 Conclusion </h2>
#
# - Fast-food items are generally high in calories, fat, sodium, and sugars, making most options nutritionally imbalanced.
#
# - Fiber is very low across most items, showing limited use of whole grains and vegetables.
#
# - Large differences exist between companies, but every chain offers both healthy and unhealthy items.
#
# - Food category (burgers, burritos, desserts, etc.) influences nutrition more strongly than company name.
#
# - Nutrient relationships show that calories are driven by multiple factors—fat, carbs, sugars, sodium, and protein.
#
# - Protein levels vary widely across items and companies—while some meals offer high protein, they often come with high fat and sodium, reducing their overall health value.
#
# - Extreme outliers appear in sodium (2000+ mg) and sugars (100+ g), which may pose health risks.
#
# - Overall, the fast-food ecosystem needs more transparency and healthier menu options.

# %% [markdown]
# <h2>💡 Recommendations </h2>
#
# <h3>● For Consumers</h3>
#
# - Prefer grilled options, salads, and smaller portions.
#
# - Avoid high-sodium and high-sugar categories like pizzas, large burgers, desserts, and sweetened drinks.
#
# - Choose items with higher fiber (salads, bowls, wraps with vegetables) and protein.
#
# <h3>● For Fast-Food Companies</h3>
#
# - Reduce sodium, added sugars, and saturated fat in core items.
#
# - Add more whole-grain and vegetable-rich options.
#
# - Provide clearer nutritional labels and highlight healthier choices.
